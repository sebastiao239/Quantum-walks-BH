# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# !c++ Hamiltoneano_Eigen.cpp -larmadillo
# !./a.out

# %%
DATA_N=np.loadtxt("Negativity.dat")

# %%
plt.plot(DATA_N[:,1],DATA_N[:,0])
#plt.xlabel('t (lattice units)')
#plt.ylabel('m(t)')
plt.show()
