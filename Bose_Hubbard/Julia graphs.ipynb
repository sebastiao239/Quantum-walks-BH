# %%
using LinearAlgebra
using Plots
using LaTeXStrings
using DelimitedFiles

# %%
;c++ Hamiltoneano_ARMA.cpp -larmadillo

# %%
;time ./a.out
# Out:
# 220 16
# HAMILTONIANO
# 220
# real	1m6.629s
# user	1m7.030s
# sys	0m1.260s

# %%
DATA_N=readdlm("Negativity.dat");
DATA_N;

# %%
fnt = Plots.font("sans-serif", 15) # Para gráficar loas labels
plot(DATA_N[:,2],DATA_N[:,1], lw=1,guidefont=fnt, fmt = :png, dpi=500,label=false)#,ls=:dash)


#plot(times,DATA_N, lw=0.8,guidefont=fnt, fmt = :png, dpi=500, label=L"\nu"*"=$n_nu"*L",\mu"*"=$n_mu",
#    title=L"M"*"=$M, "*L" N"*"=$N, "*L" J/U"*"=$J")#,ls=:dash)

# %%
N,M=3,10
binomial(N+M-1,N)
# Out:
# 220
